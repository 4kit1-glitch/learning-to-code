# %% [markdown]
# ## Dictionaries
# dictionaries is a data structure that stores data as key - value paires
#
# **A dictionary is a mapping**

# %%
numbers = {}    #
numbers
# Out:
# {}

# %%
print(type(numbers))
# Out:
# <class 'dict'>
